# %%
import pandas as pd
import os

print("Diretório atual:", os.getcwd())
print("Arquivos em data/raw:", os.listdir("../data/raw"))

df = pd.read_csv("../data/raw/products_raw.csv")

df.head()
# Out:
# Diretório atual: /Users/raitorres/Arquivos/dadosfera/RAI_TORRES_DDF_TECH_DEZEMBRO2025/notebooks
# Arquivos em data/raw: ['data-00001-of-00004.arrow', 'products_raw.csv', 'data-00000-of-00004.arrow', 'data-00002-of-00004.arrow', 'data-00003-of-00004.arrow']
#   parent_asin date_first_available  \
# 0  B0BYJ27VBB           2023-03-09
# 1  B0BVHSQLTN           2023-02-11
# 2  B0BYZ94J4G           2023-03-20
# 3  B0BYWZLFGL           2023-03-19
# 4  B0C4GHV265           2023-05-06
#
#                                                title  \
# 0  HP EliteBook 640 G9 14" FHD Business Laptop (I...
# 1  PIGOLDOG Yoga Sock s For Women,Non Slip Skid S...
# 2  8x6ft Monster Truck Photography Backdrop Car G...
# 3  Wwkhhrst Restowipes Headlight Restoration Kit,...
# 4  mignonnememe 6 Tiers Small Bathroom Storage Ca...
#
#                                          description  \
# 0  HP Sure Sense\nMalware is evolving rapidly and...
# 1  Material: The Socks made with 85% soft cotton,...
# ...
